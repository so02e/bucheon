# %%
import pandas as pd

# %%
# ?pd.read_csv
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: Union[ForwardRef('PathLike[str]'), str, IO[~T], io.RawIOBase, io.BufferedIOBase, io.TextIOBase, _io.TextIOWrapper, mmap.mmap],
#     sep=<object object at 0x000001C058AB8750>,
#     delimiter=None,
#     header='infer',
#     names=None,
#     index_col=None,
#     usecols=None,
#     squeeze=False,
#     prefix=None,
#     mangle_dupe_cols=True,
#     dtype=None,
#     engine=None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace=False,
#     skiprows=None,
#     skipfooter=0,
#     nrows=None,
#     na_values=None,
#     keep_default_na=True,
#     na_filter=True,
#     verbose=False,
#     skip_blank_lines=True,
#     parse_dates=False,
#     infer_datetime_format=False,
#     keep_date_col=False,
#     date_parser=None,
#     dayfirst=False,
#     cache_dates=True,
#     iterator=False,
#     chunksize=None,
#     compression='infer',
#     thousands=None,
#     decimal: str = '.',
# ...

# %%
school = pd.read_csv('./data/초․중등학교위치현황(완료).csv', encoding = 'ANSI')
display(school.head(5))
school.isna().sum()
# Out:
#        학교명 학교급구분 설립형태           소재지지번주소            소재지도로명주소  시도교육청명  \
# 0   상인초등학교  초등학교   공립  경기도 부천시 상동 500-3      경기도 부천시 도약로 61  경기도교육청
# 1   상동초등학교  초등학교   공립  경기도 부천시 상동 391-1      경기도 부천시 부흥로 70  경기도교육청
# 2   원미초등학교  초등학교   공립   경기도 부천시 심곡동 184     경기도 부천시 부흥로 423  경기도교육청
# 3  부천동초등학교  초등학교   공립    경기도 부천시 역곡동 31  경기도 부천시 지봉로51번길 22  경기도교육청
# 4   상지초등학교  초등학교   공립    경기도 부천시 중동 758     경기도 부천시 장말로 189  경기도교육청
#
#        교육지원청명         위도          경도
# 0  경기도부천교육지원청  37.512737  126.756481
# 1  경기도부천교육지원청  37.496878  126.750145
# 2  경기도부천교육지원청  37.489321  126.787470
# 3  경기도부천교육지원청  37.488088  126.804290
# 4  경기도부천교육지원청  37.493609  126.763526
# 학교명         0
# 학교급구분       0
# 설립형태        0
# 소재지지번주소     0
# 소재지도로명주소    0
# 시도교육청명      0
# 교육지원청명      0
# 위도          0
# 경도          0
# dtype: int64

# %%
display(school[['학교명','소재지도로명주소', '위도', '경도']].head(5))
school = school[['학교명','소재지도로명주소', '위도', '경도']]
# Out:
#        학교명            소재지도로명주소         위도          경도
# 0   상인초등학교      경기도 부천시 도약로 61  37.512737  126.756481
# 1   상동초등학교      경기도 부천시 부흥로 70  37.496878  126.750145
# 2   원미초등학교     경기도 부천시 부흥로 423  37.489321  126.787470
# 3  부천동초등학교  경기도 부천시 지봉로51번길 22  37.488088  126.804290
# 4   상지초등학교     경기도 부천시 장말로 189  37.493609  126.763526

# %%
sports = pd.read_csv('./data/체육시설현황(완료).csv', encoding = 'ANSI')
display(sports.head(5))
sports.isna().sum()
# Out:
#    시군명 시설구분명         시설명             소재지지번주소               소재지도로명주소  \
# 0  부천시  야구시설      부천 야구장   경기도 부천시 춘의동 48-25                    NaN
# 1  부천시  야구시설      까치울야구장   경기도 부천시 작동 60-8번지        경기도 부천시 길주로 691
# 2  부천시   테니스    원미공원테니스장    경기도 부천시 원미동 14-1  경기도 부천시 소사로 457 (원미동)
# 3  부천시   테니스     시청 테니스장     경기도 부천시 중동 1156                    NaN
# 4  부천시   테니스  소사1배수지테니스장  경기도 부천시 소사본동 297-5                    NaN
#
#      WGS84위도     WGS84경도
# 0  37.501091  126.796358
# 1  37.507292  126.819266
# 2  37.498423  126.795766
# 3  37.502845  126.765852
# 4  37.469462  126.804041
# 시군명          0
# 시설구분명        0
# 시설명          0
# 소재지지번주소      0
# 소재지도로명주소    27
# WGS84위도      0
# WGS84경도      0
# dtype: int64

# %%
sports = sports[['시설명', '소재지지번주소', 'WGS84위도', 'WGS84경도']]
display(sports.head(5))
# Out:
#           시설명             소재지지번주소    WGS84위도     WGS84경도
# 0      부천 야구장   경기도 부천시 춘의동 48-25  37.501091  126.796358
# 1      까치울야구장   경기도 부천시 작동 60-8번지  37.507292  126.819266
# 2    원미공원테니스장    경기도 부천시 원미동 14-1  37.498423  126.795766
# 3     시청 테니스장     경기도 부천시 중동 1156  37.502845  126.765852
# 4  소사1배수지테니스장  경기도 부천시 소사본동 297-5  37.469462  126.804041
