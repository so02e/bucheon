# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from tqdm import trange, tqdm, tqdm_notebook

# %%
grid = gpd.read_file('data/bucheongrid/bucheonjsonjson.geojson')

# %%
bike_bucheon = pd.read_csv('output/bike_bucheon.csv')
bike_bucheon = bike_bucheon.iloc[:, range(1,4)]
display(bike_bucheon)
# Out:
#           자전거대여소명         위도          경도
# 0  공공자전거대여소 부천시청역  37.504938  126.763465
# 1    공공자전거대여소 상동역  37.506069  126.754122
# 2   공공자전거대여소 신중동역  37.503068  126.775751
# 3    공공자전거대여소 부천역  37.484717  126.782677
# 4    공공자전거대여소 송내역  37.488286  126.755075
# 5   공공자전거대여소 부천시청  37.503728  126.766102

# %%
# academy
academy = pd.read_csv('./data/clean/academy.csv')
academy = academy.iloc[:, range(1,5)]
display(academy)

# concert
concert = pd.read_csv('./data/clean/concert.csv')
concert = concert.iloc[:, range(1,5)]
display(concert)

# facility
facility = pd.read_csv('./data/clean/facility.csv')
facility = facility.iloc[:, range(1,10)]
display(facility)

# hall
hall = pd.read_csv('./data/clean/hall.csv')
hall = hall.iloc[:, range(1,5)]
display(hall)

# museum
museum = pd.read_csv('./data/clean/museum.csv')
museum = museum.iloc[1:, range(1,5)]
display(museum)

# school
school = pd.read_csv('./data/clean/school.csv')
school = school.iloc[:, range(1,5)]
display(school)

# sports
sports = pd.read_csv('./data/clean/sports.csv')
sports = sports.iloc[:, range(1,5)]
display(sports)
# Out:
#                      이름                                               지번주소  \
# 0              클라비스음악학원                       경기도 부천시 고강동 480-1번지 스카이빌딩 6층
# 1          라무지카아카데미음악학원                       경기도 부천시 고강동 337번지 가람 5동 201호
# 2           고강비젼스터디보습학원                          경기도 부천시 고강동 347-4번지 3층 일부
# 3               아이빈음악학원                          경기도 부천시 고강동 389-4번지 3층 일부
# 4                고강보습학원                     경기도 부천시 고강동 370-9번지 부강빌딩 3층 일부
# ...                 ...                                                ...
# 1868        창의력해법수학보습학원  경기도 부천시 소사본동 401-7번지 풍림아파트 풍림아파트상가 203호일부,204-...
# 1869  신흥EMA(이엠에이)미술보습학원     경기도 부천시 춘의동 127번지 광성상가아파트 2층 79호내 8-12, 25-28호
# 1870             호수학교습소             경기도 부천시 중동 1102번지 꿈마을아파트 꿈마을제상가동 제204호
# 1871            천재바둑교습소                경기도 부천시 송내동 368번지 뉴서울아파트 상가동 216-2호
# 1872         부천예성피아노교습소  경기도 부천시 소사구 양지로68번길 25  범박휴먼시아 상가동 201호(범박동, 범...
#
#              위도          경도
# 0     37.525342  126.815545
# 1     37.523933  126.813580
# 2     37.526758  126.816345
# 3     37.526477  126.821402
# 4     37.527201  126.817407
# ...         ...         ...
# 1868  37.465124  126.801442
# 1869  37.505480  126.781858
# 1870  37.498899  126.779966
# 1871  37.485711  126.762718
# 1872  37.469130  126.816160
#
# [1873 rows x 4 columns]
#                이름                               도로명주소         위도          경도
# 0          상상아트센터     경기도 부천시 조마루로 2, 웅진플레이도시 2층 (상동)  37.499819  126.744884
# 1   복사골문화센터판타지아극장   경기도 부천시 장말로 107, 1층 (상동, 복사골문화센터)  37.494622  126.754219
# 2     원미초등학교      경기도 부천시 부흥로 423  37.489321  126.787470
# 3    부천동초등학교   경기도 부천시 지봉로51번길 22  37.488088  126.804290
# 4     상지초등학교      경기도 부천시 장말로 189  37.493609  126.763526
# ..       ...                  ...        ...         ...
# 120   부천고등학교   경기도 부천시 경인로92번길 70  37.479917  126.766307
# 121  부천북고등학교  경기도 부천시 삼작로256번길 40  37.518490  126.789060
# 122   역곡고등학교      경기도 부천시 안곡로 322  37.491733  126.809584
# 123   원종고등학교  경기도 부천시 소사로807번길 68  37.528500  126.800497
# 124   송내고등학교   경기도 부천시 서촌로20번길 13  37.486743  126.745360
#
# [125 rows x 4 columns]
#                   이름                           지번주소         위도          경도
# 0             부천 야구장              경기도 부천시 춘의동 48-25  37.501091  126.796358
# 1             까치울야구장              경기도 부천시 작동 60-8번지  37.507292  126.819266
# 2           원미공원테니스장               경기도 부천시 원미동 14-1  37.498423  126.795766
# 3            시청 테니스장                경기도 부천시 중동 1156  37.502845  126.765852
# 4         소사1배수지테니스장             경기도 부천시 소사본동 297-5  37.469462  126.804041
# ..               ...                            ...        ...         ...
# 542         프로 스크린골프  경기도 부천시 상동 533-3번지 아트프라자 201호  37.507652  126.750500
# 543           신정태권도장         경기도 부천시 괴안동 28-5 정석빌딩   37.478966  126.802837
# 544            충호체육관            경기도 부천시 심곡동 92-12번지  37.495572  126.783108
# 545  한국체대천지태권도(HSTM)           경기도 부천시 원종동 366-2번지   37.519616  126.807019
# 546            상승체육관           경기도 부천시 춘의동 214-33번지  37.501090  126.785682
#
# [547 rows x 4 columns]

# %%
temp = gpd.read_file('data/bucheongrid/bucheonjsonjson.geojson')
temp = temp.dropna(axis=0)
축척 = sum([
    *(temp['geometry'].bounds['maxx'] - temp['geometry'].bounds['minx']),
    *(temp['geometry'].bounds['maxy'] - temp['geometry'].bounds['miny']),
    ]) / (2 * len(temp)) / 100
도보속도 = 133.1

# %%
minute = 5
거리 = minute * 133.1 / 100 * 60

# %%
def multipolygon_to_경도(x):
    경도, 위도 = x[0].exterior.xy 
    return np.array([x for x in 경도])
def multipolygon_to_위도(x):
    경도, 위도 = x[0].exterior.xy 
    return np.array([x for x in 위도])

# %%
def get_within_nminutes_infor(Data_input, Data_infor_input, name, value=False, geojson=False):
    """
    array을 이용하여 한번에 거리를 계산 후, 도보 3분이내 거리안에 해당하는 경우의
    수, 거리의 최소,평균,최대, 값의 최소,평균,최대를 계산합니다.
    
    geojson파일인 경우 멀티폴리곤에서 각각 경위도를 계산해주고 작업을 시행합니다.
    """
    
    Data = Data_input.copy()
    Data_infor = Data_infor_input.copy()
    
    print(name + "_작업중.............")
    
    ## geojson의 경우.. 지적도의 경우 경위도를 만들어 넣어 줄 거기 때문에 try로 함수입력
    if geojson:
        try:
            Data_infor['경도'] = Data_infor['geometry'].apply(multipolygon_to_경도) 
            Data_infor['위도'] = Data_infor['geometry'].apply(multipolygon_to_위도)        
        except:
            try:
                Data_infor['경도'] = Data_infor['geometry'].centroid.x
                Data_infor['위도'] = Data_infor['geometry'].centroid.y
            except:
                pass
            
    Len1 = len(Data)
    Len2 = len(Data_infor)
    
    tt_위도 = np.repeat(Data['위도'], Len2)
    tt_위도 = np.array(tt_위도).reshape(Len1, Len2)
    diff_위도 = tt_위도 - np.array(Data_infor['위도'])

    tt_경도 = np.repeat(Data['경도'], Len2)
    tt_경도 = np.array(tt_경도).reshape(Len1, Len2)
    diff_경도 = tt_경도 - np.array(Data_infor['경도'])
    
    diff_위도 = diff_위도**2
    diff_경도 = diff_경도**2
    dist = (diff_위도 + diff_경도)**(0.5)
    
    
    Count = []
    Dist_min = []
    Dist_mean = []
    Dist_max = []
    
    Val_min = []
    Val_mean = []
    Val_max = []
    
    
    
    for idx in tqdm(Data.index):
        if geojson:
            dist_idx = np.array([i.min() for i in dist[idx]])
        else:
            dist_idx = dist[idx]
        
        temp = Data_infor.loc[dist_idx < 거리 * 축척]           
        Count.append(len(temp))
        
        try:
            Dist_min.append(dist_idx[dist_idx < 거리 * 축척].min())
            Dist_mean.append(dist_idx[dist_idx < 거리 * 축척].mean())
            Dist_max.append(dist_idx[dist_idx < 거리 * 축척].max())
        except:
            ## 수정된 부분!
            Dist_min.append(0.0025)
            Dist_mean.append(0.0025)
            Dist_max.append(0.0025)
            
    Data[name + "_" + str(minute) + "분이내수"] = Count
    Data[name + "_" + str(minute) + "분이내거리최소"] = Dist_min
    Data[name + "_" + str(minute) + "분이내거리평균"] = Dist_mean
    Data[name + "_" + str(minute) + "분이내거리최대"] = Dist_max
        
    
    if value:
        for idx in tqdm(Data.index):
            if geojson:
                dist_idx = np.array([i.min() for i in dist[idx]])
            else:
                dist_idx = dist[idx]
                
            temp = Data_infor.loc[dist_idx < 거리 * 축척]
            Val_min.append(temp[value].min())
            Val_mean.append(temp[value].mean())
            Val_max.append(temp[value].max())
            
        Data[name + "_" + str(minute) + "분이내값최소"] = Val_min
        Data[name + "_" + str(minute) + "분이내값평균"] = Val_mean
        Data[name + "_" + str(minute) + "분이내값최대"] = Val_max
        Data = Data.fillna(0)
        
        return Data
    
    else:
        return Data

# %%
academy_data = get_within_nminutes_infor(Data_input = bike_bucheon, Data_infor_input = academy, name="학원")
concert_data = get_within_nminutes_infor(Data_input = bike_bucheon, Data_infor_input = concert, name="콘서트장")
facility_data = get_within_nminutes_infor(Data_input = bike_bucheon, Data_infor_input = facility, name="공공시설")
hall_data = get_within_nminutes_infor(Data_input = bike_bucheon, Data_infor_input = hall, name="홀")
museum_data = get_within_nminutes_infor(Data_input = bike_bucheon, Data_infor_input = museum, name="미술관박물관(전시시설)")
school_data = get_within_nminutes_infor(Data_input = bike_bucheon, Data_infor_input = school, name="학교")
sports_data = get_within_nminutes_infor(Data_input = bike_bucheon, Data_infor_input = sports, name="체육시설")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 601.52it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1203.13it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 2006.04it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1002.54it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1203.53it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 546.32it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
# 학원_작업중.............
# 콘서트장_작업중.............
# 공공시설_작업중.............
# 홀_작업중.............
# 미술관박물관(전시시설)_작업중.............
# 학교_작업중.............
# 체육시설_작업중.............
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 859.52it/s]

# %%
print(academy_data)
print('\n')
print(concert_data)
print('\n')
print(facility_data)
print('\n')
print(hall_data)
print('\n')
print(museum_data)
print('\n')
print(school_data)
print('\n')
print(sports_data)
# Out:
#           자전거대여소명         위도          경도  학원_5분이내수  학원_5분이내거리최소  학원_5분이내거리평균  \
# 0  공공자전거대여소 부천시청역  37.504938  126.763465        87     0.000192     0.002150
# 1    공공자전거대여소 상동역  37.506069  126.754122       263     0.000709     0.002220
# 2   공공자전거대여소 신중동역  37.503068  126.775751        81     0.001031     0.002917
# 3    공공자전거대여소 부천역  37.484717  126.782677        40     0.000715     0.002323
# 4    공공자전거대여소 송내역  37.488286  126.755075        32     0.001487     0.003092
# 5   공공자전거대여소 부천시청  37.503728  126.766102       114     0.001165     0.002887
#
#    학원_5분이내거리최대
# 0     0.003974
# 1     0.003952
# 2     0.004011
# 3     0.003958
# 4     0.004082
# 5     0.004086
#
#
#           자전거대여소명         위도          경도  콘서트장_5분이내수  콘서트장_5분이내거리최소  \
# 0  공공자전거대여소 부천시청역  37.504938  126.763465           0       0.002500
# 1    공공자전거대여소 상동역  37.506069  126.754122           1       0.003187
# 2   공공자전거대여소 신중동역  37.503068  126.775751           0       0.002500
# 3    공공자전거대여소 부천역  37.484717  126.782677           0       0.002500
# 4    공공자전거대여소 송내역  37.488286  126.755075           0       0.002500
# 5   공공자전거대여소 부천시청  37.503728  126.766102           0       0.002500
#
#    콘서트장_5분이내거리평균  콘서트장_5분이내거리최대
# 0       0.002500       0.002500
# 1       0.003187       0.003187
# 2       0.002500       0.002500
# 3       0.002500       0.002500
# 4       0.002500       0.002500
# 5       0.002500       0.002500
#
#
#           자전거대여소명         위도          경도  공공시설_5분이내수  공공시설_5분이내거리최소  \
# 0  공공자전거대여소 부천시청역  37.504938  126.763465           0         0.0025
# 1    공공자전거대여소 상동역  37.506069  126.754122           0         0.0025
# 2   공공자전거대여소 신중동역  37.503068  126.775751           0         0.0025
# 3    공공자전거대여소 부천역  37.484717  126.782677           0         0.0025
# 4    공공자전거대여소 송내역  37.488286  126.755075           0         0.0025
# 5   공공자전거대여소 부천시청  37.503728  126.766102           0         0.0025
#
#    공공시설_5분이내거리평균  공공시설_5분이내거리최대
# 0         0.0025         0.0025
# 1         0.0025         0.0025
# 2         0.0025         0.0025
# 3         0.0025         0.0025
# 4         0.0025         0.0025
# 5         0.0025         0.0025
#
#
#           자전거대여소명         위도          경도  홀_5분이내수  홀_5분이내거리최소  홀_5분이내거리평균  \
# 0  공공자전거대여소 부천시청역  37.504938  126.763465        0    0.002500    0.002500
# 1    공공자전거대여소 상동역  37.506069  126.754122        1    0.003187    0.003187
# 2   공공자전거대여소 신중동역  37.503068  126.775751        0    0.002500    0.002500
# 3    공공자전거대여소 부천역  37.484717  126.782677        0    0.002500    0.002500
# 4    공공자전거대여소 송내역  37.488286  126.755075        0    0.002500    0.002500
# 5   공공자전거대여소 부천시청  37.503728  126.766102        0    0.002500    0.002500
#
#    홀_5분이내거리최대
# 0    0.002500
# 1    0.003187
# 2    0.002500
# 3    0.002500
# 4    0.002500
# 5    0.002500
#
#
#           자전거대여소명         위도          경도  미술관박물관(전시시설)_5분이내수  \
# 0  공공자전거대여소 부천시청역  37.504938  126.763465                   0
# 1    공공자전거대여소 상동역  37.506069  126.754122                   0
# 2   공공자전거대여소 신중동역  37.503068  126.775751                   0
# 3    공공자전거대여소 부천역  37.484717  126.782677                   0
# 4    공공자전거대여소 송내역  37.488286  126.755075                   0
# 5   공공자전거대여소 부천시청  37.503728  126.766102                   0
#
#    미술관박물관(전시시설)_5분이내거리최소  미술관박물관(전시시설)_5분이내거리평균  미술관박물관(전시시설)_5분이내거리최대
# 0                 0.0025                 0.0025                 0.0025
# 1                 0.0025                 0.0025                 0.0025
# 2                 0.0025                 0.0025                 0.0025
# 3                 0.0025                 0.0025                 0.0025
# 4                 0.0025                 0.0025                 0.0025
# 5                 0.0025                 0.0025                 0.0025
#
#
#           자전거대여소명         위도          경도  학교_5분이내수  학교_5분이내거리최소  학교_5분이내거리평균  \
# 0  공공자전거대여소 부천시청역  37.504938  126.763465         3     0.002004     0.002762
# 1    공공자전거대여소 상동역  37.506069  126.754122         0     0.002500     0.002500
# 2   공공자전거대여소 신중동역  37.503068  126.775751         4     0.003406     0.003680
# 3    공공자전거대여소 부천역  37.484717  126.782677         1     0.003312     0.003312
# 4    공공자전거대여소 송내역  37.488286  126.755075         0     0.002500     0.002500
# 5   공공자전거대여소 부천시청  37.503728  126.766102         1     0.003843     0.003843
#
#    학교_5분이내거리최대
# 0     0.003911
# 1     0.002500
# 2     0.003897
# 3     0.003312
# 4     0.002500
# 5     0.003843
#
#
#           자전거대여소명         위도          경도  체육시설_5분이내수  체육시설_5분이내거리최소  \
# 0  공공자전거대여소 부천시청역  37.504938  126.763465          14       0.000192
# 1    공공자전거대여소 상동역  37.506069  126.754122          30       0.000883
# 2   공공자전거대여소 신중동역  37.503068  126.775751          13       0.001785
# 3    공공자전거대여소 부천역  37.484717  126.782677           9       0.001321
# 4    공공자전거대여소 송내역  37.488286  126.755075           8       0.002954
# 5   공공자전거대여소 부천시청  37.503728  126.766102          16       0.000918
#
#    체육시설_5분이내거리평균  체육시설_5분이내거리최대
# 0       0.002018       0.003550
# 1       0.002081       0.003952
# 2       0.003129       0.004011
# 3       0.002870       0.003634
# 4       0.003445       0.003951
# 5       0.003022       0.004075

# %%
dataframe = pd.DataFrame(academy_data)
dataframe.to_csv("../bucheon/output/var_academy.csv")

dataframe2 = pd.DataFrame(concert_data)
dataframe2.to_csv("../bucheon/output/var_concert.csv")

dataframe3 = pd.DataFrame(facility_data)
dataframe3.to_csv("../bucheon/output/var_facility.csv")

dataframe4 = pd.DataFrame(hall_data)
dataframe4.to_csv("../bucheon/output/var_hall.csv")

dataframe5 = pd.DataFrame(museum_data)
dataframe5.to_csv("../bucheon/output/var_museum.csv")

dataframe6 = pd.DataFrame(school_data)
dataframe6.to_csv("../bucheon/output/var_school.csv")

dataframe7 = pd.DataFrame(sports_data)
dataframe7.to_csv("../bucheon/output/var_sports.csv")
